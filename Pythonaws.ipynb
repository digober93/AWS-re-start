# %%
print("Hola")
# Out:
# Hola

# %%
a='hitch'
y=2000
v=True
print('la pelicula es '+str(a)+' '+str(y)+' '+str(v))
# Out:
# la pelicula es hitch 2000 True

# %%
print(f"nombre: {a}, año: {y}")
# Out:
# nombre: hitch, año: 2000

# %%
nombre=input("nombre de la pelicula: ")
print(f"la pelicula es :{nombre}")

# %%
peliculas=[
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]

year=[
    1994,
    2008,
    2010,
    1994,
    1999,
    2014,
    2019,
    2000,
    1997,
    2001
]

watched=[
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False
]

# %%
#opc 1
for i in range (len(peliculas)):
                print("la peliculas es: ", peliculas[i], "estrenada en el año: ", year[i], "y la has visto?: ", watched[i])
# Out:
# la peliculas es:  The Shawshank Redemption estrenada en el año:  1994 y la has visto?:  True
# la peliculas es:  The Dark Knight estrenada en el año:  2008 y la has visto?:  False
# la peliculas es:  Inception estrenada en el año:  2010 y la has visto?:  True
# la peliculas es:  Pulp Fiction estrenada en el año:  1994 y la has visto?:  False
# la peliculas es:  The Matrix estrenada en el año:  1999 y la has visto?:  True
# la peliculas es:  Interstellar estrenada en el año:  2014 y la has visto?:  False
# la peliculas es:  Parasite estrenada en el año:  2019 y la has visto?:  True
# la peliculas es:  Gladiator estrenada en el año:  2000 y la has visto?:  False
# la peliculas es:  Titanic estrenada en el año:  1997 y la has visto?:  True
# la peliculas es:  The Lord of the Rings: The Fellowship of the Ring estrenada en el año:  2001 y la has visto?:  False

# %%
def peliculas_loop (peliculas, year, watched):
    for peliculas, year, watched in zip (peliculas, year, watched):
        print(peliculas, year, watched)

peliculas_loop(peliculas, year, watched)
# Out:
# The Shawshank Redemption 1994 True
# The Dark Knight 2008 False
# Inception 2010 True
# Pulp Fiction 1994 False
# The Matrix 1999 True
# Interstellar 2014 False
# Parasite 2019 True
# Gladiator 2000 False
# Titanic 1997 True
# The Lord of the Rings: The Fellowship of the Ring 2001 False

# %%
print("commit para v2") #comment
# Out:
# commit para v2
